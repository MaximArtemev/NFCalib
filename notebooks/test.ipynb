# %%
from utils import data_utils

# %%
data = data_utils.GAS()
# Out:
# /Users/max/PycharmProjects/NFCalib/utils/data_utils/gas.py:50: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   B = A.as_matrix().sum(axis=1)
# /Users/max/PycharmProjects/NFCalib/utils/data_utils/gas.py:70: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   data = load_data_and_clean(file).as_matrix()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=(20, 20))
data.show_histograms('trn')
# Out:
# /Users/max/PycharmProjects/NFCalib/utils/data_utils/misc_utils.py:252: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   ax[i, j].hist(data[:, i], n_bins, normed=True)
